# %%
import sys, numpy, cv2, matplotlib
print(sys.executable)
print("python", sys.version.split()[0])
print("numpy", numpy.__version__, numpy.__file__)
print("opencv", cv2.__version__, cv2.__file__)
print("matplotlib", matplotlib.__version__)
# Out:
# C:\Users\Adity\miniforge3\envs\ac-cv\python.exe
# python 3.12.13
# numpy 2.5.1 C:\Users\Adity\miniforge3\envs\ac-cv\Lib\site-packages\numpy\__init__.py
# opencv 5.0.0 C:\Users\Adity\miniforge3\envs\ac-cv\Lib\site-packages\cv2\__init__.py
# matplotlib 3.11.1
